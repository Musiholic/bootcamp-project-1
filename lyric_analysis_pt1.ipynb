# %% [markdown]
# # Most popular words

# %%
# Dependencies
import pandas as pd
import os
import csv
import re
import matplotlib.pyplot as plt

# %%
# Import lyric data
data = pd.read_csv("Resources/Lyrics.csv")

# %%
# Create columns for top 5 words in each song and create list to hold words
toplist = []

df = data
df[["Top Words (1)"]] = ""
df[["Top Words (2)"]] = ""
df[["Top Words (3)"]] = ""
df[["Top Words (4)"]] = ""
df[["Top Words (5)"]] = ""
df
# Out:
#        Unnamed: 0         Artist Name  \
# 0               0        Post Malone
# 1               1         Juice WRLD
# 2               2       Lil Uzi Vert
# 3               3            J. Cole
# 4               4        Post Malone
# ...           ...                 ...
# 11079       11079     The Band Perry
# 11080       11080  Justin Timberlake
# 11081       11081      Mike WiLL Made
# 11082       11082          The Vamps
# 11083       11083                 JAY
#
#                                         Song Name  \
# 0      Sunflower  SpiderMan: Into the SpiderVerse
# 1                                    Lucid Dreams
# 2                                   XO TOUR Llif3
# 3                                  No Role Modelz
# 4                                        rockstar
# ...                                           ...
# 11079                              If I Die Young
# 11080                             Not a Bad Thing
# 11081                                      It  23
# ...

# %%
# Loop through data (break lyrics into a list of words)


# Read lyrics and break into single words for analysis
for i in range(len(df)):

    if df.iloc[i,3] != "0":

        lyrics = df.iloc[i,3]


        try:

            lyrics = lyrics.lower()

        except AttributeError:
            pass


        lyrics = re.sub('[^a-z\ \']+', " ", lyrics)
        words = list(lyrics.split())
        words = pd.Series(words)
        word_count = words.value_counts()
        words_df = pd.DataFrame({"Count":word_count})
        

        
        
        # Remove these words
        words_df = words_df.loc[words_df.index != "i"]
        words_df = words_df.loc[words_df.index != "you"]
        words_df = words_df.loc[words_df.index != "he"]
        words_df = words_df.loc[words_df.index != "she"]
        words_df = words_df.loc[words_df.index != "it"]
        words_df = words_df.loc[words_df.index != "we"]
        words_df = words_df.loc[words_df.index != "you"]
        words_df = words_df.loc[words_df.index != "they"]
        words_df = words_df.loc[words_df.index != "me"]
        words_df = words_df.loc[words_df.index != "you"]
        words_df = words_df.loc[words_df.index != "him"]
        words_df = words_df.loc[words_df.index != "her"]
        words_df = words_df.loc[words_df.index != "it"]
        words_df = words_df.loc[words_df.index != "us"]
        words_df = words_df.loc[words_df.index != "you"]
        words_df = words_df.loc[words_df.index != "them"]
        words_df = words_df.loc[words_df.index != "mine"]
        words_df = words_df.loc[words_df.index != "yours"]
        words_df = words_df.loc[words_df.index != "his"]
        words_df = words_df.loc[words_df.index != "hers"]
        words_df = words_df.loc[words_df.index != "it's"]
        words_df = words_df.loc[words_df.index != "ours"]
        words_df = words_df.loc[words_df.index != "yours"]
        words_df = words_df.loc[words_df.index != "a"]
        words_df = words_df.loc[words_df.index != "you're"]
        words_df = words_df.loc[words_df.index != "the"]
        words_df = words_df.loc[words_df.index != "ooh"]
        words_df = words_df.loc[words_df.index != "be"]
        words_df = words_df.loc[words_df.index != "my"]
        words_df = words_df.loc[words_df.index != "the"]
        words_df = words_df.loc[words_df.index != "to"]
        words_df = words_df.loc[words_df.index != "are"]
        words_df = words_df.loc[words_df.index != "and"]
        words_df = words_df.loc[words_df.index != "i'm"]
        words_df = words_df.loc[words_df.index != "in"]
        words_df = words_df.loc[words_df.index != "ayy"]
        words_df = words_df.loc[words_df.index != "on"]
        words_df = words_df.loc[words_df.index != "i'll"]
        words_df = words_df.loc[words_df.index != "for"]
        words_df = words_df.loc[words_df.index != "was"]
        words_df = words_df.loc[words_df.index != "she'll"]
        words_df = words_df.loc[words_df.index != "he'll"]
        words_df = words_df.loc[words_df.index != "you'll"]
        words_df = words_df.loc[words_df.index != "oh"]
        words_df = words_df.loc[words_df.index != "do"]
        words_df = words_df.loc[words_df.index != "but"]
        words_df = words_df.loc[words_df.index != "ay"]
        words_df = words_df.loc[words_df.index != "so"]
        words_df = words_df.loc[words_df.index != "like"]
        words_df = words_df.loc[words_df.index != "nigga"]
        words_df = words_df.loc[words_df.index != "niggas"]
        words_df = words_df.loc[words_df.index != "bitch"]
        words_df = words_df.loc[words_df.index != "bitches"]
        words_df = words_df.loc[words_df.index != "of"]
        words_df = words_df.loc[words_df.index != "or"]
        words_df = words_df.loc[words_df.index != "your"]
        words_df = words_df.loc[words_df.index != "eh"]
        words_df = words_df.loc[words_df.index != "is"]
        words_df = words_df.loc[words_df.index != "as"]
        words_df = words_df.loc[words_df.index != "fuck"]
        words_df = words_df.loc[words_df.index != "if"]
        words_df = words_df.loc[words_df.index != "i'ma"]
        words_df = words_df.loc[words_df.index != "no"]
        words_df = words_df.loc[words_df.index != "ah"]
        words_df = words_df.loc[words_df.index != "ha"]
        words_df = words_df.loc[words_df.index != "too"]
        words_df = words_df.loc[words_df.index != "shit"]
        words_df = words_df.loc[words_df.index != "ey"]
        words_df = words_df.loc[words_df.index != "that"]
        words_df = words_df.loc[words_df.index != "uh"]
        words_df = words_df.loc[words_df.index != "at"]
        words_df = words_df.loc[words_df.index != "n"]
        words_df = words_df.loc[words_df.index != "up"]
        words_df = words_df.loc[words_df.index != "you've"]
        words_df = words_df.loc[words_df.index != "i've"]
        words_df = words_df.loc[words_df.index != "were"]
        words_df = words_df.loc[words_df.index != "yah"]
        words_df = words_df.loc[words_df.index != "don't"]
        words_df = words_df.loc[words_df.index != "am"]
        words_df = words_df.loc[words_df.index != "'em"]
        words_df = words_df.loc[words_df.index != "i've"]
        words_df = words_df.loc[words_df.index != "z"]
        words_df = words_df.loc[words_df.index != "bish"]
        words_df = words_df.loc[words_df.index != "l"]
        words_df = words_df.loc[words_df.index != "go"]
        words_df = words_df.loc[words_df.index != "am"]
        words_df = words_df.loc[words_df.index != "it'll"]
        words_df = words_df.loc[words_df.index != "don't"]
        words_df = words_df.loc[words_df.index != "ee"]
        words_df = words_df.loc[words_df.index != "nah"]
        words_df = words_df.loc[words_df.index != "all"]
        words_df = words_df.loc[words_df.index != "fucks"]
        words_df = words_df.loc[words_df.index != "fucking"]
        words_df = words_df.loc[words_df.index != "x"]
        words_df = words_df.loc[words_df.index != "ya"]
        words_df = words_df.loc[words_df.index != "y'all"]
        words_df = words_df.loc[words_df.index != "got"]
        words_df = words_df.loc[words_df.index != "get"]
        words_df = words_df.loc[words_df.index != "just"]
        words_df = words_df.loc[words_df.index != "i'd"]
        words_df = words_df.loc[words_df.index != "won't"]
        words_df = words_df.loc[words_df.index != "a'int"]
        words_df = words_df.loc[words_df.index != "o"]
        words_df = words_df.loc[words_df.index != "like"]
        words_df = words_df.loc[words_df.index != "fuckin'"]
        words_df = words_df.loc[words_df.index != "'bout"]
        words_df = words_df.loc[words_df.index != "let"]
        words_df = words_df.loc[words_df.index != "through"]
        words_df = words_df.loc[words_df.index != "what"]
        words_df = words_df.loc[words_df.index != "yeah"]
        words_df = words_df.loc[words_df.index != "m's"]
        words_df = words_df.loc[words_df.index != "ain't"]
        words_df = words_df.loc[words_df.index != "from"]
        words_df = words_df.loc[words_df.index != "with"]
        words_df = words_df.loc[words_df.index != "an"]
        words_df = words_df.loc[words_df.index != "h"]
        words_df = words_df.loc[words_df.index != "s"]
        words_df = words_df.loc[words_df.index != "can"]
        words_df = words_df.loc[words_df.index != "from"]
        words_df = words_df.loc[words_df.index != "know"]
        words_df = words_df.loc[words_df.index != "can't"]
        words_df = words_df.loc[words_df.index != "doin'"]
        words_df = words_df.loc[words_df.index != "cum"]
        words_df = words_df.loc[words_df.index != "that's"]
        words_df = words_df.loc[words_df.index != "suicide"]
        words_df = words_df.loc[words_df.index != "this"]
        words_df = words_df.loc[words_df.index != "let's"]
        words_df = words_df.loc[words_df.index != "aren't"]
        words_df = words_df.loc[words_df.index != "we're"]
        words_df = words_df.loc[words_df.index != "when"]
        words_df = words_df.loc[words_df.index != "wanna"]
        words_df = words_df.loc[words_df.index != "how"]
        words_df = words_df.loc[words_df.index != "than"]
        words_df = words_df.loc[words_df.index != "then"]
        words_df = words_df.loc[words_df.index != "out"]
        words_df = words_df.loc[words_df.index != "been"]
        words_df = words_df.loc[words_df.index != "'cause"]
        words_df = words_df.loc[words_df.index != "not"]
        words_df = words_df.loc[words_df.index != "come"]
        words_df = words_df.loc[words_df.index != "take"]
        words_df = words_df.loc[words_df.index != "some"]
        words_df = words_df.loc[words_df.index != "off"]
        words_df = words_df.loc[words_df.index != "gon'"]
        words_df = words_df.loc[words_df.index != "have"]
        words_df = words_df.loc[words_df.index != "could"]
        words_df = words_df.loc[words_df.index != "gotta"]
        words_df = words_df.loc[words_df.index != "gonna"]
        words_df = words_df.loc[words_df.index != "these"]
        words_df = words_df.loc[words_df.index != "why"]
        words_df = words_df.loc[words_df.index != "que"]
        words_df = words_df.loc[words_df.index != "here"]
        words_df = words_df.loc[words_df.index != "had"]
        words_df = words_df.loc[words_df.index != "about"]
        words_df = words_df.loc[words_df.index != "pussy"]
        words_df = words_df.loc[words_df.index != "would"]
        words_df = words_df.loc[words_df.index != "thing"]
        words_df = words_df.loc[words_df.index != "things"]
        words_df = words_df.loc[words_df.index != "we've"]
        words_df = words_df.loc[words_df.index != "p"]
        words_df = words_df.loc[words_df.index != "r"]
        words_df = words_df.loc[words_df.index != "m"]
        words_df = words_df.loc[words_df.index != "shitting"]
        words_df = words_df.loc[words_df.index != "t"]
        words_df = words_df.loc[words_df.index != "who"]
        words_df = words_df.loc[words_df.index != "e"]
        words_df = words_df.loc[words_df.index != "fucked"]
        words_df = words_df.loc[words_df.index != "where"]
        words_df = words_df.loc[words_df.index != "will"]
        words_df = words_df.loc[words_df.index != "cr"]
        words_df = words_df.loc[words_df.index != "la"]
        words_df = words_df.loc[words_df.index != "y"]
        words_df = words_df.loc[words_df.index != "e"]
        words_df = words_df.loc[words_df.index != "its"]
        words_df = words_df.loc[words_df.index != "by"]
        words_df = words_df.loc[words_df.index != "everything's"]
        words_df = words_df.loc[words_df.index != "tryna"]
        words_df = words_df.loc[words_df.index != "she's"]
        words_df = words_df.loc[words_df.index != "isn't"]
        words_df = words_df.loc[words_df.index != "'a"]
        words_df = words_df.loc[words_df.index != "suicidal"]
        words_df = words_df.loc[words_df.index != "ass"]
        words_df = words_df.loc[words_df.index != "huh"]
        words_df = words_df.loc[words_df.index != "titties"]
        words_df = words_df.loc[words_df.index != "who's"]
        words_df = words_df.loc[words_df.index != "make"]
        words_df = words_df.loc[words_df.index != "still"]
        words_df = words_df.loc[words_df.index != "hey"]

        # Sort values
        words_df = words_df.sort_values(by="Count",ascending=False)
        

        # Display
        top5 = words_df.head(5)

        try:

            # Record word
            word1 = top5.index[0]
            word2 = top5.index[1]
            word3 = top5.index[2]
            word4 = top5.index[3]
            word5 = top5.index[4]

            # Add word to df
            df.iloc[i,4] = word1
            df.iloc[i,5] = word2
            df.iloc[i,6] = word3
            df.iloc[i,7] = word4
            df.iloc[i,8] = word5

            # Add word to top-words list
            toplist.append(word1)
            toplist.append(word2)
            toplist.append(word3)
            toplist.append(word4)
            toplist.append(word5)
        except IndexError:
            pass

# %%
# display table
df.head()
# Out:
#    Unnamed: 0    Artist Name                                   Song Name  \
# 0           0   Post Malone   Sunflower  SpiderMan: Into the SpiderVerse
# 1           1    Juice WRLD                                 Lucid Dreams
# 2           2  Lil Uzi Vert                                XO TOUR Llif3
# 3           3       J. Cole                               No Role Modelz
# 4           4   Post Malone                                     rockstar
#
#                                               Lyrics Top Words (1)  \
# 0  [Swae Lee:]\nAyy, ayy, ayy, ayy (ooh)\nOoh, oo...     sunflower
# 1  Enviyon on the mix\nNo, no, no, no\nNo-no, no,...         heart
# 2  Are you alright?\nI'm alright, I'm quite alrig...          dead
# 3  First things first rest in peace Uncle Phil\nF...       shallow
# 4  [Post Malone:]\nHahahahaha\nTank God\n\nAyy, I...      rockstar
#
#   Top Words (2) Top Words (3) Top Words (4) Top Words (5)
# 0         wreck           bad          baby        unless
# ...

# %%
# Get value counts of each word for each song and save
export = df[["Artist Name","Song Name","Top Words (1)","Top Words (2)","Top Words (3)","Top Words (4)","Top Words (5)"]]
export.to_csv("Resources/top_words.csv")

# %%
# Display top 25 words
t = toplist
top_list = pd.Series(t)




top_list = top_list.value_counts()
top_list.head(25)
# Out:
# love     1001
# now       816
# baby      738
# want      579
# never     558
# back      547
# down      528
# one       515
# time      470
# say       453
# need      434
# see       418
# way       381
# feel      370
# right     329
# keep      315
# tell      307
# girl      292
# money     242
# more      238
# think     234
# good      224
# said      224
# give      224
# man       213
# Name: count, dtype: int64

# %%
# List of top 25 words
thewords = ["love","now","baby","never","want","back","down","one","time","say","man","need","see","way","feel","keep","right","tell","girl","money","more","think","give","good","life"]

# %%
# Determine what songs contain words from the top 25 words

# Create list for songs
sglt = []

# Generate list of songs containing a top 25 word
thesongs1 = df["Top Words (1)"].isin(thewords)
thesongs2 = df["Top Words (2)"].isin(thewords)
thesongs3 = df["Top Words (3)"].isin(thewords)
thesongs4 = df["Top Words (4)"].isin(thewords)
thesongs5 = df["Top Words (5)"].isin(thewords)


# Generate df of songs that contain song in top 25
thesongs1 = df["Song Name"].loc[thesongs1 == True]
thesongs2 = df["Song Name"].loc[thesongs2 == True]
thesongs3 = df["Song Name"].loc[thesongs3 == True]
thesongs4 = df["Song Name"].loc[thesongs4 == True]
thesongs5 = df["Song Name"].loc[thesongs5 == True]


# Reset index
thesongs1 = thesongs1.reset_index()
thesongs2 = thesongs2.reset_index()
thesongs3 = thesongs3.reset_index()
thesongs4 = thesongs4.reset_index()
thesongs5 = thesongs5.reset_index()


# Generate list of the songs
thesongs1 = thesongs1[["Song Name"]]
thesongs2 = thesongs2[["Song Name"]]
thesongs3 = thesongs3[["Song Name"]]
thesongs4 = thesongs4[["Song Name"]]
thesongs5 = thesongs5[["Song Name"]]


# Add songs to song list
sglt.append(thesongs1["Song Name"])
sglt.append(thesongs2["Song Name"])
sglt.append(thesongs3["Song Name"])
sglt.append(thesongs4["Song Name"])
sglt.append(thesongs5["Song Name"])

# %%
# Check for data
thesongs1
# Out:
#                    Song Name
# 0     All Girls Are The Same
# 1               I Fall Apart
# 2                  One Dance
# 3                   good 4 u
# 4                    Robbery
# ...                      ...
# 2120              Hot N Cold
# 2121              Wilderness
# 2122                 Love Me
# 2123               I Love It
# 2124         Not a Bad Thing
#
# [2125 rows x 1 columns]

# %%
# Import original data
top10k = pd.read_csv("Resources/top_10k_streamed_songs.csv")

# %%
# display data
top10k
# Out:
#        Position         Artist Name  \
# 0             1        Post Malone
# 1             2         Juice WRLD
# 2             3       Lil Uzi Vert
# 3             4            J. Cole
# 4             5        Post Malone
# ...         ...                 ...
# 11079     11080     The Band Perry
# 11080     11081  Justin Timberlake
# 11081     11082      Mike WiLL Made
# 11082     11083          The Vamps
# 11083     11084                 JAY
#
#                                         Song Name  Days  Top 10 (xTimes)  \
# 0      Sunflower  SpiderMan: Into the SpiderVerse  1506              302
# 1                                    Lucid Dreams  1673              178
# 2                                   XO TOUR Llif3  1853              212
# 3                                  No Role Modelz  2547                6
# 4                                        rockstar  1223              186
# ...                                           ...   ...              ...
# ...

# %%
# Determine what songs contain top 25 words

top10k1 = top10k["Song Name"].isin(thesongs1["Song Name"])
top10k12 = top10k1
top10k2 = top10k["Song Name"].isin(thesongs2["Song Name"])
top10k22 = top10k2
top10k3 = top10k["Song Name"].isin(thesongs3["Song Name"])
top10k32 = top10k3
top10k4 = top10k["Song Name"].isin(thesongs4["Song Name"])
top10k42 = top10k4
top10k5 = top10k["Song Name"].isin(thesongs5["Song Name"])
top10k52 = top10k5

top10k1 = top10k.loc[top10k1 == True]
top10k2 = top10k.loc[top10k2 == True]
top10k3 = top10k.loc[top10k3 == True]
top10k4 = top10k.loc[top10k4 == True]
top10k5 = top10k.loc[top10k5 == True]

# %%
# Organize data
top10k1 = top10k1.reset_index()
top10k2 = top10k2.reset_index()
top10k3 = top10k3.reset_index()
top10k4 = top10k4.reset_index()
top10k5 = top10k5.reset_index()

top10k1 = top10k1[["Song Name","Total Streams"]]
top10k2 = top10k2[["Song Name","Total Streams"]]
top10k3 = top10k3[["Song Name","Total Streams"]]
top10k4 = top10k4[["Song Name","Total Streams"]]
top10k5 = top10k5[["Song Name","Total Streams"]]

top10k1
# Out:
#                    Song Name  Total Streams
# 0     All Girls Are The Same      613872384
# 1            Congratulations      546036924
# 2               I Fall Apart      543144261
# 3               MIDDLE CHILD      481985952
# 4                  One Dance      454267392
# ...                      ...            ...
# 2436              Hot N Cold          57154
# 2437              Wilderness          57117
# 2438                 Love Me          56290
# 2439               I Love It          51604
# 2440         Not a Bad Thing          49512
#
# [2441 rows x 2 columns]

# %%
# create new column and set boolean to false
df[["Used a Top Word"]] = False

# %%
# Perform loop to check if word is in song



for i in range(len(top10k12)):

    if (top10k12[i] == True) or (top10k22[i] == True) or (top10k32[i] == True) or (top10k42[i] == True) or (top10k52[i] == True):

        df.iloc[i,9] = not False
        




df
# Out:
#        Unnamed: 0         Artist Name  \
# 0               0        Post Malone
# 1               1         Juice WRLD
# 2               2       Lil Uzi Vert
# 3               3            J. Cole
# 4               4        Post Malone
# ...           ...                 ...
# 11079       11079     The Band Perry
# 11080       11080  Justin Timberlake
# 11081       11081      Mike WiLL Made
# 11082       11082          The Vamps
# 11083       11083                 JAY
#
#                                         Song Name  \
# 0      Sunflower  SpiderMan: Into the SpiderVerse
# 1                                    Lucid Dreams
# 2                                   XO TOUR Llif3
# 3                                  No Role Modelz
# 4                                        rockstar
# ...                                           ...
# 11079                              If I Die Young
# 11080                             Not a Bad Thing
# 11081                                      It  23
# ...

# %%
# Save
df.to_csv("Resources/lyrics_and_top_words.csv")

# %%
# Merge to get stream values
complete = df.merge(top10k, on="Song Name")


# Organize
complete = complete[["Artist Name_x","Song Name","Total Streams","Used a Top Word"]]

# %%
# display data
complete
# Out:
#             Artist Name_x                                   Song Name  \
# 0            Post Malone   Sunflower  SpiderMan: Into the SpiderVerse
# 1             Juice WRLD                                 Lucid Dreams
# 2             Juice WRLD                                 Lucid Dreams
# 3             Joseph Yap                                 Lucid Dreams
# 4             Joseph Yap                                 Lucid Dreams
# ...                   ...                                         ...
# 14302     The Band Perry                               If I Die Young
# 14303  Justin Timberlake                              Not a Bad Thing
# 14304      Mike WiLL Made                                      It  23
# 14305          The Vamps                              Somebody To You
# 14306                 JAY                               Z  Holy Grail
#
#        Total Streams  Used a Top Word
# 0          883369738             True
# 1          864832399             True
# ...

# %%
# Calculations
counts = complete["Used a Top Word"].value_counts()
true = 179508364891/8953
false = 94016553770/5354
counts
# Out:
# Used a Top Word
# True     8975
# False    5332
# Name: count, dtype: int64

# %%
# Sum up totals
hg1 = complete.groupby(complete["Used a Top Word"]).sum("Total Streams")
hg1[["Average"]] = ""
hg1
# Out:
#                  Total Streams Average
# Used a Top Word
# False              93727808093
# True              179797110568

# %%
# Input new values
hg1.iloc[0,1] = false
hg1.iloc[1,1] = true
hg1
# Out:
#                  Total Streams          Average
# Used a Top Word
# False              93727808093  17560058.604781
# True              179797110568  20050079.849324

# %%
# Plot chart
x = hg1.index
y = hg1["Average"]

plt.figure(figsize=(10,10))
plt.bar(x,y)
plt.xlabel("Song Uses a Word From The Top 25 Words")
plt.xticks(ticks=[0,1],labels=["No","Yes"])
plt.ylabel("Total Number of Streams (ten-millions)")
plt.title("Use of Top 25 Word vs. Number of Streams")
# Out:
# Text(0.5, 1.0, 'Use of Top 25 Word vs. Number of Streams')

# %%
# Conclusion
difference = true - false

print(f"On average, a song that uses a Top 25 Word will receive {round(difference)} more streams than a song that doesn't use a Top 25 Word.")
# Out:
# On average, a song that uses a Top 25 Word will receive 2490021 more streams than a song that doesn't use a Top 25 Word.
